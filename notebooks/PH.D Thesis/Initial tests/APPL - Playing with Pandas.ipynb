# %%
import pandas as pd
appl=pd.read_csv("/home/cetrulin/Desktop/Andres/data/APPL/AAPL_prices_sample.csv", parse_dates=['date'])
#df1=pd.read_csv("C:/PythonHow/file1.csv",header=None)
print(appl)
# Out:
#         Unnamed: 0 symbol       date      time     bid     ofr  bidsiz  \
# 0                1   AAPL 2014-01-02  04:00:00  455.39    0.00       1
# 1                2   AAPL 2014-01-02  04:00:00  553.50  558.00       2
# 2                3   AAPL 2014-01-02  04:00:01  455.39  561.02       1
# 3                4   AAPL 2014-01-02  04:00:45  552.10  558.00       1
# 4                5   AAPL 2014-01-02  04:00:51  552.10  558.40       1
# 5                6   AAPL 2014-01-02  04:00:51  552.10  558.80       1
# 6                7   AAPL 2014-01-02  04:00:51  552.10  559.00       1
# 7                8   AAPL 2014-01-02  04:01:14  553.00  559.00       1
# 8                9   AAPL 2014-01-02  04:01:30  553.01  561.02       1
# 9               10   AAPL 2014-01-02  04:01:43  553.01  559.00       1
# 10              11   AAPL 2014-01-02  04:01:44  553.05  559.00       1
# 11              12   AAPL 2014-01-02  04:01:49  455.39  559.00       1
# ...

# %%
appl['date']
# Out:
# 0        2014-01-02
# 1        2014-01-02
# 2        2014-01-02
# 3        2014-01-02
# 4        2014-01-02
# 5        2014-01-02
# 6        2014-01-02
# 7        2014-01-02
# 8        2014-01-02
# 9        2014-01-02
# 10       2014-01-02
# 11       2014-01-02
# 12       2014-01-02
# 13       2014-01-02
# 14       2014-01-02
# 15       2014-01-02
# 16       2014-01-02
# 17       2014-01-02
# 18       2014-01-02
# 19       2014-01-02
# 20       2014-01-02
# 21       2014-01-02
# 22       2014-01-02
# 23       2014-01-02
# 24       2014-01-02
# 25       2014-01-02
# 26       2014-01-02
# 27       2014-01-02
# 28       2014-01-02
# 29       2014-01-02
#             ...
# 389811   2014-01-02
# 389812   2014-01-02
# 389813   2014-01-02
# 389814   2014-01-02
# 389815   2014-01-02
# 389816   2014-01-02
# 389817   2014-01-02
# 389818   2014-01-02
# 389819   2014-01-02
# 389820   2014-01-02
# 389821   2014-01-02
# 389822   2014-01-02
# 389823   2014-01-02
# 389824   2014-01-02
# ...

# %%
import matplotlib.pyplot as plt   # Import matplotlib
# This line is necessary for the plot to appear in a Jupyter notebook
# %matplotlib inline
# Control the default size of figures in this Jupyter notebook
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)   # Change the size of plots
 
appl['bid'].plot(figsize=(16, 12))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
appl.truncate(before='2015-01-01')['bid'].plot(figsize=(16, 12))

# %%
appl.dtypes
# Out:
# Unnamed: 0             int64
# symbol                object
# date          datetime64[ns]
# time                  object
# bid                  float64
# ofr                  float64
# bidsiz                 int64
# ofrsiz                 int64
# mode                   int64
# ex                    object
# mmid                 float64
# dtype: object

# %%
appl.plot(grid = True)

# %%
plot(diff(appl),ylab='Differenced APPL Sales')
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-26-49145bdfe1aa> in <module>()
# ----> 1 plot(diff(appl),ylab='Differenced APPL Sales')
#
# /anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in diff(a, n, axis)
#    1576         return diff(a[slice1]-a[slice2], n-1, axis=axis)
#    1577     else:
# -> 1578         return a[slice1]-a[slice2]
#    1579
#    1580
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
plot(diff(log10(appl)),ylab='Differenced Log (Tractor Sales)')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-27-b90e61db939b> in <module>()
# ----> 1 plot(diff(log10(appl)),ylab='Differenced Log (Tractor Sales)')
#
# AttributeError: 'int' object has no attribute 'log10'

# %%
df['lag1']=df['col name'].shift(1)
df['lag2']=df['col name'].shift(2)

# %%
import pandas as pd
df=pd.read_csv("/home/cetrulin/Desktop/Andres/data/APPL/AAPL_prices_sample.csv", parse_dates=['date'])
#df1=pd.read_csv("C:/PythonHow/file1.csv",header=None)
print(df)
# Out:
#         Unnamed: 0 symbol       date      time     bid     ofr  bidsiz  \
# 0                1   AAPL 2014-01-02  04:00:00  455.39    0.00       1
# 1                2   AAPL 2014-01-02  04:00:00  553.50  558.00       2
# 2                3   AAPL 2014-01-02  04:00:01  455.39  561.02       1
# 3                4   AAPL 2014-01-02  04:00:45  552.10  558.00       1
# 4                5   AAPL 2014-01-02  04:00:51  552.10  558.40       1
# 5                6   AAPL 2014-01-02  04:00:51  552.10  558.80       1
# 6                7   AAPL 2014-01-02  04:00:51  552.10  559.00       1
# 7                8   AAPL 2014-01-02  04:01:14  553.00  559.00       1
# 8                9   AAPL 2014-01-02  04:01:30  553.01  561.02       1
# 9               10   AAPL 2014-01-02  04:01:43  553.01  559.00       1
# 10              11   AAPL 2014-01-02  04:01:44  553.05  559.00       1
# 11              12   AAPL 2014-01-02  04:01:49  455.39  559.00       1
# ...
