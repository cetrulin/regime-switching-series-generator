# %%
import cryptocompare
import datetime

# %%
cryptocompare.get_coin_list(format=False)
# Out:
# {'MTL': {'Algorithm': 'N/A',
#   'CoinName': 'Metal',
#   'FullName': 'Metal (MTL)',
#   'FullyPremined': '0',
#   'Id': '179164',
#   'ImageUrl': '/media/1383743/mtl.png',
#   'Name': 'MTL',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoPP',
#   'SortOrder': '1308',
#   'Sponsored': False,
#   'Symbol': 'MTL',
#   'TotalCoinSupply': '66588888',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/mtl/overview'},
#  'POKER': {'Algorithm': 'Scrypt',
#   'CoinName': 'PokerCoin',
#   'FullName': 'PokerCoin (POKER)',
#   'FullyPremined': '0',
#   'Id': '799922',
#   'ImageUrl': '/media/27011048/poker.jpg',
#   'Name': 'POKER',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS/PoW',
#   'SortOrder': '2424',
#   'Sponsored': False,
#   'Symbol': 'POKER',
#   'TotalCoinSupply': '466666667',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/poker/overview'},
#  'RAIN': {'Algorithm': 'X11',
#   'CoinName': 'Condensate',
#   'FullName': 'Condensate (RAIN)',
#   'FullyPremined': '0',
# ...

# %%
cryptocompare.get_price('BTC',curr='USD',full=True)
#cryptocompare.get_price('BTC')
#cryptocompare.get_price(['BTC','ETH'],['EUR','GBP'])
# Out:
# {'DISPLAY': {'BTC': {'USD': {'CHANGE24HOUR': '$ 137.09',
#     'CHANGEDAY': '$ -2.95',
#     'CHANGEPCT24HOUR': '1.56',
#     'CHANGEPCTDAY': '-0.03',
#     'FROMSYMBOL': 'Ƀ',
#     'HIGH24HOUR': '$ 9,063.62',
#     'HIGHDAY': '$ 9,043.98',
#     'LASTMARKET': 'Kraken',
#     'LASTTRADEID': '1524415855.4269',
#     'LASTUPDATE': 'Just now',
#     'LASTVOLUME': 'Ƀ 0.3000',
#     'LASTVOLUMETO': '$ 2,682.18',
#     'LOW24HOUR': '$ 8,745.75',
#     'LOWDAY': '$ 8,827.82',
#     'MARKET': 'CryptoCompare Index',
#     'MKTCAP': '$ 151.74 B',
#     'OPEN24HOUR': '$ 8,795.68',
#     'OPENDAY': '$ 8,935.72',
#     'PRICE': '$ 8,932.77',
#     'SUPPLY': 'Ƀ 16,986,575.0',
#     'TOSYMBOL': '$',
#     'TOTALVOLUME24H': 'Ƀ 395.65 K',
#     'TOTALVOLUME24HTO': '$ 3,534.19 M',
#     'VOLUME24HOUR': 'Ƀ 64,619.5',
#     'VOLUME24HOURTO': '$ 577,189,035.0',
#     'VOLUMEDAY': 'Ƀ 49,009.4',
#     'VOLUMEDAYTO': '$ 438,872,874.8'}}},
#  'RAW': {'BTC': {'USD': {'CHANGE24HOUR': 137.09000000000015,
# ...

# %%
cryptocompare.get_historical_price('BTC', 'USD', datetime.datetime(2017,6,6))
# Out:
# {'BTC': {'USD': 2870.5}}
